# %%
#importing necessary Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.metrics.pairwise import cosine_similarity
import difflib
import nltk
import pickle

# %%
# Ensure NLTK resources are downloaded
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Load dataset
df = pd.read_csv(r"C:\Users\Abhishek\Desktop\project done\movie_rm_s\updated_bollywood_movies.csv")

# Text Cleaning
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Abhishek\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Abhishek\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Abhishek\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    return ' '.join(tokens)

df.fillna('', inplace=True)
df['movie_name'] = df['movie_name'].apply(preprocess_text)
df['genre'] = df['genre'].apply(preprocess_text)
df['cast'] = df['cast'].apply(preprocess_text)
df['director'] = df['director'].apply(preprocess_text)
df['overview'] = df['overview'].apply(preprocess_text)

# Tokenization
max_words = 10000
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(df['overview'])

# Save the tokenizer for future use
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(df['overview'])
padded_sequences = pad_sequences(sequences, maxlen=200)

# Encode labels for multi-class classification (genre, cast, etc.)
label_encoder = LabelEncoder()
df['genre_encoded'] = label_encoder.fit_transform(df['genre'])

# %%
# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['genre_encoded'], test_size=0.3, random_state=42)

# %%
# Model architecture: LSTM
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, input_length=200))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(len(df['genre_encoded'].unique()), activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.3)

# Save model for future use
model.save('movie_recommendation_system_lstm.keras')
# Out:
# C:\Users\Abhishek\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.0236 - loss: 5.2816 - val_accuracy: 0.0801 - val_loss: 4.5936
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 19s 551ms/step - accuracy: 0.1003 - loss: 4.4724 - val_accuracy: 0.0693 - val_loss: 4.4094
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 20s 581ms/step - accuracy: 0.0726 - loss: 4.3565 - val_accuracy: 0.0801 - val_loss: 4.4018
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 581ms/step - accuracy: 0.0905 - loss: 4.2650 - val_accuracy: 0.0801 - val_loss: 4.4128
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 628ms/step - accuracy: 0.0935 - loss: 4.2606 - val_accuracy: 0.0801 - val_loss: 4.4206
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 23s 672ms/step - accuracy: 0.0862 - loss: 4.3069 - val_accuracy: 0.0801 - val_loss: 4.4256
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 609ms/step - accuracy: 0.0855 - loss: 4.2883 - val_accuracy: 0.0736 - val_loss: 4.4360
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 20s 599ms/step - accuracy: 0.0705 - loss: 4.3288 - val_accuracy: 0.0801 - val_loss: 4.4349
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 22s 664ms/step - accuracy: 0.0914 - loss: 4.1429 - val_accuracy: 0.0866 - val_loss: 4.4846
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 20s 600ms/step - accuracy: 0.0885 - loss: 3.9188 - val_accuracy: 0.0563 - val_loss: 4.6015

# %%
# Function to handle spelling mistakes
def correct_spelling(input_string, possible_values):
    close_matches = difflib.get_close_matches(input_string.lower(), possible_values, n=1)
    return close_matches[0] if close_matches else input_string

# %%
def recommend_movies(movie_name, genre, casting, year_of_release, year_range, top_n):
    # Ensure the 'year_of_release' is treated as numeric
    df['year_of_release'] = pd.to_numeric(df['year_of_release'], errors='coerce')

    # Initialize the filtered DataFrame based on initial filters
    df_filtered = df

    # Filter based on movie name if provided
    if movie_name:
        df_filtered = df_filtered[df_filtered['movie_name'].str.contains(movie_name, case=False, na=False)]

    # Filter based on genre if provided
    if genre:
        df_filtered = df_filtered[df_filtered['genre'].str.contains(genre, case=False, na=False)]

    # Filter based on casting if provided
    if casting:
        df_filtered = df_filtered[df_filtered['cast'].str.contains(casting, case=False, na=False)]

    # Filter based on year of release if provided
    if year_of_release:
        df_filtered = df_filtered[df_filtered['year_of_release'] == year_of_release]

    # Filter based on year range if provided
    if year_range:
        df_filtered = df_filtered[(df_filtered['year_of_release'] >= year_range[0]) & 
                                  (df_filtered['year_of_release'] <= year_range[1])]

    # Here, you can replace this with actual predictions from the model (mock predictions used)
    predictions = np.random.rand(df_filtered.shape[0])  # Mock predictions

    # Add predictions to the filtered DataFrame for display
    df_filtered['predictions'] = predictions

    # Sort by predictions and return the top N
    return df_filtered.nlargest(top_n, 'predictions')


def interactive_recommendation():
    while True:
        # Ask user for inputs one by one
        movie_name = input("Enter movie name (or leave blank): ")
        genre = input("Enter genre (or leave blank): ")
        casting = input("Enter casting (or leave blank): ")
        year_of_release = input("Enter year of release (or leave blank): ")
        
        # Convert year_of_release to int if provided
        if year_of_release:
            try:
                year_of_release = int(year_of_release)
            except ValueError:
                year_of_release = None

        # Ask for year range if desired
        year_range_input = input("Enter year range (e.g., 2000-2010) or leave blank: ")
        if year_range_input:
            try:
                year_range = list(map(int, year_range_input.split('-')))
            except ValueError:
                year_range = None
        else:
            year_range = None

        # Get top recommendations
        top_10 = recommend_movies(movie_name, genre, casting, year_of_release, year_range, top_n=10)
        if top_10.empty:
            print("No suitable recommendations found based on your search.")
        else:
            print("Top 10 Movie Recommendations:")
            print(top_10)

        # Ask if user wants more recommendations
        response = input("Would you like to see more recommendations? (yes/no): ").strip().lower()
        if response == 'yes':
            top_20 = recommend_movies(movie_name, genre, casting, year_of_release, year_range, top_n=20)
            print("Top 20 Movie Recommendations:")
            print(top_20)

            response = input("Would you like to see even more recommendations? (yes/no): ").strip().lower()
            if response == 'yes':
                top_50 = recommend_movies(movie_name, genre, casting, year_of_release, year_range, top_n=50)
                print("Top 50 Movie Recommendations:")
                print(top_50)
            else:
                print("ok....I will glad to help you again....Thank you!")
        elif response == 'no':
            print("ok....I will glad to help you again....Thank you!")
        else:
            print("ok....I will glad to help you again....Thank you!")
            break

# %%
# Call the function without parameters to start the interaction
interactive_recommendation()
# Out:
# Enter movie name (or leave blank):
# Enter genre (or leave blank):
# Enter casting (or leave blank):
# Enter year of release (or leave blank):  2010-2020
# Enter year range (e.g., 2000-2010) or leave blank:
# Top 10 Movie Recommendations:
#       sl no IMDB_movie_id        movie_name  year_of_release  \
# 1814   1887    tt19888200              maid           2022.0
# 842     867     tt1170399        c kkompany           2008.0
# 915     890     tt1223922              blue           2009.0
# 1080   1126     tt2357489           zanjeer           2013.0
# 1341   1399     tt6143422        kadvi hawa           2017.0
# 1459   1496     tt2150177  bhaiaji superhit           2018.0
# 1225   1258     tt5207116  x : past present           2015.0
# 1519   1575     tt7255568    student year 2           2019.0
# 692     720     tt0443208               rog           2005.0
# 2086   1963    tt24964506          underbug           2023.0
#
#                              genre  \
# 1814                       romance
# 842      comedy , drama , thriller
# 915   action , adventure , mystery
# 1080        action , crime , drama
# 1341                         drama
# 1459       action , comedy , drama
# 1225     drama , mystery , romance
# 1519       action , comedy , drama
# 692   mystery , romance , thriller
# 2086                        horror
#
#                                                overview  \
# 1814  grew word `` made `` realize soulmate `` maid ...
# 842   three luck men adapts strategical idea extorti...
# 915   group people , facing lot challenge , decide h...
# 1080  acp vijay khanna transferred mumbai deal oil m...
# 1341  story farmer bank recovery agent , whose life ...
# 1459   goon try win wife back making movie love story .
# 1225  filmmaker mid-life crisis meet mysterious youn...
# 1519  student must face bully overcome hurdle , acad...
# 692   lonely insomniac detective fall love dead woma...
# 2086  india ravaged sectarian violence eve independe...
#
#                                                director  \
# 1814                                     swagger sharma
# 842                                        sachin yardi
# 915                                     anthony d'souza
# 1080                                     apoorva lakhia
# 1341                                  nila madhab panda
# 1459                                      neeraj pathak
# 1225  hemant gaba , pratim d. gupta , sudhish kamath...
# 1519                                     punit malhotra
# 692                                 himanshu brahmbhatt
# 2086                                   shujaat saudagar
#
#                                                    cast  genre_encoded  \
# 1814  lavina khanchandani , bhupender singh rawat , ...            215
# 842   tusshar kapoor , anupam kher , rajpal naurang ...            107
# 915   akshay kumar , sanjay dutt , lara dutta , zaye...              8
# 1080  ram charan , priyanka chopra jonas , sanjay du...             26
# 1341  sanjay mishra , ranvir shorey , tillotama shom...            142
# 1459  sunny deol , preity g zinta , arshad warsi , a...             17
# 1225  rajat kapoor , radhika apte , bidita bag , pia...            178
# 1519  tiger shroff , ananya panday , tara sutaria , ...             17
# 692   irrfan khan , ilene hamann , himanshu malik , ...            213
# 2086         hussain dalal , areenah fatima , ali fazal            198
#
#       predictions
# 1814     0.999936
# 842      0.999745
# 915      0.999621
# 1080     0.999062
# 1341     0.998873
# 1459     0.998682
# 1225     0.998682
# 1519     0.998676
# 692      0.998575
# 2086     0.997529
# Would you like to see more recommendations? (yes/no):  yes
# Top 20 Movie Recommendations:
#       sl no IMDB_movie_id                    movie_name  year_of_release  \
# 1725   1728    tt11213600            sardar ka grandson           2021.0
# 36       35     tt0059893                          waqt           1965.0
# 1231   1265     tt4023852               welcome karachi           2015.0
# 791     825     tt0860454  mp3 : mera pehla pehla pyaar           2007.0
# 112     119     tt0178186                        aandhi           1975.0
# 2032   1907    tt18561736           great indian family           2023.0
# 877     854     tt0476550            god tussi great ho           2008.0
# 510     532     tt0289725                          jung           2000.0
# 40       47     tt0137361                       anupama           1966.0
# 1938   2013    tt28534557        cantt road : beginning           2023.0
# 2142   2172     tt5785132                     aankhen 2              NaN
# 1857   1776    tt15145764                        freddy           2022.0
# 300     289     tt0173283                         swarg           1990.0
# 1817   1884    tt15820306                       chuhiya           2022.0
# 123     126     tt0214832                    kalicharan           1976.0
# 1195   1162     tt3036740                    humshakals           2014.0
# 1621   1664    tt10230414                   serious men           2020.0
# 679     659     tt0422950                  phir milenge           2004.0
# 192     205     tt0085361                        coolie           1983.0
# 485     502     tt0195002                        kaun ?           1999.0
#
#                            genre  \
# 1725    comedy , drama , romance
# 36               drama , romance
# 1231       action , comedy , war
# 791     comedy , drama , musical
# 112              drama , romance
# 2032                      family
# 877     comedy , drama , fantasy
# 510       action , crime , drama
# 40               drama , romance
# 1938                       crime
# 2142                    thriller
# 1857   drama , mystery , romance
# 300                        drama
# 1817
# 123   action , adventure , crime
# 1195    comedy , drama , romance
# 1621              comedy , drama
# 679                        drama
# 192      action , comedy , drama
# 485           mystery , thriller
#
#                                                overview  \
# 1725  devoted grandson embarks complicated comic jou...
# 36    member family separated natural disaster . sev...
# 1231  two men india land karachi , pakistan , withou...
# 791   delhi-based rohan sood life wealthy lifestyle ...
# 112   hotel manager j.k. ( sanjeev kumar ) work . on...
# 2032  ved vyas tripathi , aka bhajan kumar , devout ...
# 877   tv anchor keep blaming god unsuccessful life ....
# 510   police officer frantic search compatible bone-...
# 40    mohan sharma ( tarun bose ) workaholic whose l...
# 1938  peculiar place located somewhere outskirt myst...
# 2142  aankhen 2 based disgraced banker hire three bl...
# 1857  line love obsession blur romantic thriller pac...
# 300   krishna loyal master treat like god . unfortun...
# 1817  story comprehensive look education system , ca...
# 123   police officer go undercover catch wealthy rep...
# 1195  comedy centered around three people lookalike ...
# 1621  tormented 'under-privileged ' societal status ...
# 679   tamanna sahni ( shilpa shetty ) dedicated staf...
# 192   iqbal get separated mother brother flood , bec...
# 485   alone house , woman hears news serial killer l...
#
#                            director  \
# 1725                   kaashvi nair
# 36                      yash chopra
# 1231                ashish r. mohan
# 791                   robbie grewal
# 112                          gulzar
# 2032          vijay krishna acharya
# 877                    rumi jaffery
# 510                    sanjay gupta
# 40             hrishikesh mukherjee
# 1938                adarsh raisahab
# 2142                    abhinay deo
# 1857                shashanka ghosh
# 300                    david dhawan
# 1817                    hyder kazmi
# 123                    subhash ghai
# 1195                     sajid khan
# 1621  sudhir mishra , sachin krishn
# 679                         revathi
# 192     manmohan desai , prayag raj
# 485                 ram gopal varma
#
#                                                    cast  genre_encoded  \
# 1725  john abraham , rakul preet singh , aditi rao h...            104
# 36    sunil dutt , sadhana shivdasani , raaj kumar ,...            180
# 1231  arshad warsi , jackky bhagnani , lauren gottli...             24
# 791   menekka arora , sarthak bhasin , sagar chawla ...            102
# 112   suchitra sen , sanjeev kumar , om shivpuri , m...            180
# 2032  alka amin , bhuvan arora , manushi chhillar , ...            189
# 877   amitabh bachchan , salman khan , priyanka chop...             98
# 510   sanjay dutt , jackie shroff , aditya pancholi ...             26
# 40    dharmendra , sharmila tagore , shashikala jawa...            180
# 1938  sharvary joshi , ashok rabari , nischay rana ,...            128
# 2142  amitabh bachchan , sanjay dutt , sidharth malh...            222
# 1857  kartik aaryan , alaya f , karan pandit , sajja...            178
# 300     rajesh khanna , govinda , madhavi , juhi chawla            142
# 1817  hyder kazmi , onkar da manikpuri , anupama pra...              0
# 123   shatrughan sinha , reena roy , ajit khan , pre...              5
# 1195  saif ali khan , riteish deshmukh , ram kapoor ...            104
# 1621  nawazuddin siddiqui , nassar , aakshath da , i...             96
# 679   salman khan , abhishek bachchan , shilpa shett...            142
# 192   amitabh bachchan , waheeda rehman , rishi kapo...             17
# 485   urmila matondkar , manoj bajpayee , sushant singh            214
#
#       predictions
# 1725     0.999984
# 36       0.999777
# 1231     0.998591
# 791      0.998083
# 112      0.997654
# 2032     0.997279
# 877      0.995931
# 510      0.995270
# 40       0.994973
# 1938     0.994238
# 2142     0.993425
# 1857     0.993393
# 300      0.992175
# 1817     0.991620
# 123      0.991164
# 1195     0.989719
# 1621     0.988106
# 679      0.988049
# 192      0.987921
# 485      0.987864
# Would you like to see even more recommendations? (yes/no):
# ok....I will glad to help you again....Thank you!
# Enter movie name (or leave blank):  love
# Enter genre (or leave blank):  horror
# Enter casting (or leave blank):
# Enter year of release (or leave blank):
# Enter year range (e.g., 2000-2010) or leave blank:  2010-2020
# No suitable recommendations found based on your search.
# Would you like to see more recommendations? (yes/no):  no
# ok....I will glad to help you again....Thank you!
# Enter movie name (or leave blank):
# Enter genre (or leave blank):
# Enter casting (or leave blank):
# Enter year of release (or leave blank):
# Enter year range (e.g., 2000-2010) or leave blank:
# Top 10 Movie Recommendations:
#       sl no IMDB_movie_id                 movie_name  year_of_release  \
# 1218   1240     tt3495030         dum laga ke haisha           2015.0
# 925     959     tt1373156    karthik calling karthik           2010.0
# 1779   1862    tt14767926               # homecoming           2022.0
# 1281   1314     tt4900716               kapoor & son           2016.0
# 1769   1715     tt9614452                   big bull           2021.0
# 873     850     tt1292703    oye lucky ! lucky oye !           2008.0
# 1491   1464     tt5935704                  padmaavat           2018.0
# 738     705     tt0475645  vaah ! life ho toh aisi !           2005.0
# 868     864     tt1288638                dasvidaniya           2008.0
# 1441   1490     tt6580564                        102           2018.0
#
#                           genre  \
# 1218   comedy , drama , romance
# 925   drama , mystery , romance
# 1779            drama , musical
# 1281    comedy , drama , family
# 1769  biography , crime , drama
# 873      comedy , crime , drama
# 1491  drama , history , romance
# 738     comedy , drama , family
# 868              comedy , drama
# 1441             comedy , drama
#
#                                                overview  \
# 1218  prem oversized wife sandhya supposed spend lif...
# 925   much abused loner achieves success , even win ...
# 1779  group `` friend '' `` misfit '' , formed popul...
# 1281  story two brother visit dysfunctional family g...
# 1769  story film based real event financial market t...
# 873   lovinder singh , thief custody facing trial , ...
# 1491  set medieval rajasthan , queen padmavati marri...
# 738   adi chachu face dilemma - 's big one ! told go...
# 868   man love make `` to-do list '' make one last b...
# 1441  102 2018 comedy-drama film , legendary actor a...
#
#                    director  \
# 1218        sharat katariya
# 925           vijay lalwani
# 1779     soumyajit majumdar
# 1281           shakun batra
# 1769          kookie gulati
# 873        dibakar banerjee
# 1491  sanjay leela bhansali
# 738        mahesh manjrekar
# 868           shashant shah
# 1441           umesh shukla
#
#                                                    cast  genre_encoded  \
# 1218  bhumi pednekar , ayushmann khurrana , sanjay m...            104
# 925   farhan akhtar , deepika padukone , ram kapoor ...            178
# 1779  sayani gupta , tushar pandey , hussain dalal ,...            173
# 1281  rishi kapoor , rajat kapoor , ratna pathak sha...             97
# 1769  abhishek bachchan , nikita dutta , ileana d'cr...             81
# 873   abhay deol , paresh rawal , nitu chandra , arc...             92
# 1491  deepika padukone , ranveer singh , shahid kapo...            161
# 738   shahid kapoor , amrita rao , sanjay dutt , ars...             97
# 868   vinay pathak , sarita joshi , rajat kapoor , s...             96
# 1441  amitabh bachchan , rishi kapoor , vijay raaz ,...             96
#
#       predictions
# 1218     0.999193
# 925      0.996656
# 1779     0.996575
# 1281     0.996156
# 1769     0.995919
# 873      0.995591
# 1491     0.995517
# 738      0.995445
# 868      0.993706
# 1441     0.992128
# Would you like to see more recommendations? (yes/no):
# ok....I will glad to help you again....Thank you!

# %%
# Save user input for future use
user_inputs = {
    'movie_name': 'inception',
    'genre': 'sci-fi',
    'casting': 'leonardo dicaprio',
    'year_of_release': 2010
}

with open('user_inputs.pickle', 'wb') as handle:
    pickle.dump(user_inputs, handle, protocol=pickle.HIGHEST_PROTOCOL)
